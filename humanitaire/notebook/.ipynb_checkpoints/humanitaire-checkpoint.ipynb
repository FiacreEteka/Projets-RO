# %%
import pandas as pd
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.opt import SolverFactory

# Importation des données
df_depots = pd.read_csv("../data/depots.csv", index_col=0)
df_zones = pd.read_csv("../data/zones.csv", index_col=0)
df_cout_transports = pd.read_csv("../data/couts_transport.csv", index_col=0)
df_parametres = pd.read_csv("../data/parametres.csv", index_col=0)
df_distances = pd.read_csv("../data/distances.csv", index_col=0)


# Paramètres
depots = list(df_depots.index)
zones = list(df_zones.index)
cout_fixe = df_depots['cout_fixe'].to_dict()
capacite = df_depots['capacite'].to_dict()
demandes = df_zones['demande'].to_dict()
nb_depot_max = df_parametres.loc['nb_depots_max', 'valeur']
budget_max = df_parametres.loc['budget_max', 'valeur']

cout_transport = {}
distances = {}
for i in depots:
    for j in zones:
        cout_transport[i, j] = df_cout_transports.loc[i,j]
        distances[i, j] = df_distances.loc[i,j]

# Modèle
model = pyo.ConcreteModel()

# Variables de décision
model.x = pyo.Var(depots, zones, bounds=(0, None), within = Reals)
model.y = pyo.Var(depots, within = Binary)

x = model.x
y = model.y

# Fonction onjectif
model.obj = pyo.Objective(expr = sum(cout_transport[i, j]*x[i, j] for i in depots for j in zones) + sum(y[i]*cout_fixe[i] for i in depots), sense = pyo.minimize)

# Contraintes
model.c1 = pyo.ConstraintList()
for j in zones:
    model.c1.add(expr = sum(x[i, j] for i in depots) == demandes[j])

model.c2 = pyo.ConstraintList()
for i in depots:
    model.c2.add(expr = sum(x[i, j] for j in zones) <= capacite[i]*y[i])

model.c3 = pyo.Constraint(expr = sum(y[i] for i in depots) <= nb_depot_max)

model.c4 = pyo.Constraint(
    expr=sum(cout_fixe[i]*y[i] for i in depots) + 
         sum(cout_transport[i,j]*x[i,j] for i in depots for j in zones) 
         <= budget_max
)

# Résolution
opt = SolverFactory('glpk')
opt.solve(model)

print(f"Coût total : {pyo.value(model.obj):,.0f} FCFA\n")

depots_ouverts = [i for i in depots if pyo.value(y[i]) == 1]
print(f"Dépôts ouverts ({len(depots_ouverts)}) : {', '.join(depots_ouverts)}\n")

for i in depots_ouverts:
    charge = sum(pyo.value(x[i, j]) for j in zones if pyo.value(x[i, j]) > 0)
    print(f"Dépôt {i} — Charge : {charge:.0f}/{capacite[i]} ")
    for j in zones:
        if pyo.value(x[i, j]) > 0:
            print(f"{j} : {pyo.value(x[i, j]):.0f} ")
    print()
# Out:
# Coût total : 5,620,420 FCFA
#
# Dépôts ouverts (3) : Parakou, Abomey, Natitingou
#
# Dépôt Parakou — Charge : 335/400
# Kandi : 80
# Bembéréké : 80
# Nikki : 90
# Savalou : 75
# Bohicon : 10
#
# Dépôt Abomey — Charge : 300/300
# Bohicon : 85
# Lokossa : 85
# Ouidah : 70
# Comè : 60
#
# Dépôt Natitingou — Charge : 250/250
# Malanville : 120
# Kandi : 20
# Djougou : 110

# %%
import folium

carte = folium.Map(location=[9.0, 2.3], zoom_start=7)

couleurs = {
    'Parakou': 'blue',
    'Abomey': 'green',
    'Natitingou': 'red',
    'Cotonou': 'purple'
}

for i in depots:
    if pyo.value(y[i]) == 1:
        folium.Marker(
            location=[df_depots.loc[i, 'latitude'], df_depots.loc[i, 'longitude']],
            popup=f"<b>Dépôt : {i}</b><br>Capacité : {capacite[i]} <br>Coût fixe : {cout_fixe[i]:,} FCFA",
            icon=folium.Icon(color=couleurs.get(i, 'gray'), icon='home')
        ).add_to(carte)

for j in zones:
    folium.CircleMarker(
        location=[df_zones.loc[j, 'latitude'], df_zones.loc[j, 'longitude']],
        radius=8,
        color='orange',
        fill=True,
        fill_color='orange',
        fill_opacity=0.7,
        popup=f"<b>Zone : {j}</b><br>Demande : {demandes[j]} "
    ).add_to(carte)


for i in depots:
    if pyo.value(y[i]) == 1:
        for j in zones:
            val = pyo.value(x[i, j])
            if val and val > 0:
                folium.PolyLine(
                    locations=[
                        [df_depots.loc[i, 'latitude'], df_depots.loc[i, 'longitude']],
                        [df_zones.loc[j, 'latitude'], df_zones.loc[j, 'longitude']]
                    ],
                    color=couleurs.get(i, 'gray'),
                    weight=max(1, val/20),  # épaisseur proportionnelle au flux
                    opacity=0.7,
                    popup=f"{i} → {j} : {val:.0f} t"
                ).add_to(carte)


legende = """
<div style="position: fixed; bottom: 30px; left: 30px; z-index: 1000;
     background: white; padding: 10px; border-radius: 8px;
     border: 2px solid grey; font-size: 13px;">
    <b>Légende</b><br>
    🏠 Dépôt ouvert<br>
    🟠 Zone sinistrée<br>
    — Flux de livraison
</div>
"""
carte.get_root().html.add_child(folium.Element(legende))


carte.save('../outputs/carte_humanitaire.html')
# Afficher dans Jupyter
carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf45c2fe5dd54c394895efd203f83386 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; bottom: 30px; left: 30px; z-index: 1000;
#      background: white; padding: 10px; border-radius: 8px;
#      border: 2px solid grey; font-size: 13px;&quot;&gt;
#     &lt;b&gt;Légende&lt;/b&gt;&lt;br&gt;
#     🏠 Dépôt ouvert&lt;br&gt;
#     🟠 Zone sinistrée&lt;br&gt;
#     — Flux de livraison
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf45c2fe5dd54c394895efd203f83386&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf45c2fe5dd54c394895efd203f83386 = L.map(
#                 &quot;map_bf45c2fe5dd54c394895efd203f83386&quot;,
#                 {
#                     center: [9.0, 2.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d754d7c157320fa857d786d178f5f224 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d754d7c157320fa857d786d178f5f224.addTo(map_bf45c2fe5dd54c394895efd203f83386);
#
#
#             var marker_0ab5da44e40b1f4fa9849f558ad34ff4 = L.marker(
#                 [9.3372, 2.6282],
#                 {
# }
#             ).addTo(map_bf45c2fe5dd54c394895efd203f83386);
#
#
#             var icon_1214a4b8b0692ea35b63911cf03e1203 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f0ffa1a0703053a5404205a7f574ef19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22e6a6e01c8bd37917210ddedc0514a0 = $(`&lt;div id=&quot;html_22e6a6e01c8bd37917210ddedc0514a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dépôt : Parakou&lt;/b&gt;&lt;br&gt;Capacité : 400 &lt;br&gt;Coût fixe : 12,000 FCFA&lt;/div&gt;`)[0];
#                 popup_f0ffa1a0703053a5404205a7f574ef19.setContent(html_22e6a6e01c8bd37917210ddedc0514a0);
#
#
#
#         marker_0ab5da44e40b1f4fa9849f558ad34ff4.bindPopup(popup_f0ffa1a0703053a5404205a7f574ef19)
#         ;
#
#
#
#
#                 marker_0ab5da44e40b1f4fa9849f558ad34ff4.setIcon(icon_1214a4b8b0692ea35b63911cf03e1203);
#
#
#             var marker_53c5640d23eb7293f3022a4eeb9a8ab8 = L.marker(
#                 [7.1833, 1.9833],
#                 {
# }
#             ).addTo(map_bf45c2fe5dd54c394895efd203f83386);
#
#
#             var icon_7e41866ad217465b546f27d3878d2283 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_df376e9a2620631a744081c230ca34c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88ca4ef084f32eaaaf6c05cbd7560d54 = $(`&lt;div id=&quot;html_88ca4ef084f32eaaaf6c05cbd7560d54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dépôt : Abomey&lt;/b&gt;&lt;br&gt;Capacité : 300 &lt;br&gt;Coût fixe : 10,000 FCFA&lt;/div&gt;`)[0];
#                 popup_df376e9a2620631a744081c230ca34c0.setContent(html_88ca4ef084f32eaaaf6c05cbd7560d54);
#
#
#
#         marker_53c5640d23eb7293f3022a4eeb9a8ab8.bindPopup(popup_df376e9a2620631a744081c230ca34c0)
#         ;
#
#
#
#
#                 marker_53c5640d23eb7293f3022a4eeb9a8ab8.setIcon(icon_7e41866ad217465b546f27d3878d2283);
#
#
#             var marker_f70a69730cf6ff7bc79701f542050582 = L.marker(
#                 [10.3167, 1.3833],
#                 {
# }
#             ).addTo(map_bf45c2fe5dd54c394895efd203f83386);
#
#
#             var icon_8e210c1e1fcd5b62d47c8fbc270be82b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a1c5891eaf970d95b35b11c221c065d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99197223c3a65dfe5cb10f7b6f6b7eaf = $(`&lt;div id=&quot;html_99197223c3a65dfe5cb10f7b6f6b7eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&g
