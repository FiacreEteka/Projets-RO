# %%
import pandas as pd
import pulp as plp
solver = plp.GLPK_CMD()


# Lecture des fichiers comportant les données
aliment_df = pd.read_csv('../data/aliments.csv', index_col=0)
besoin_df = pd.read_csv('../data/besoins.csv', index_col = 0)

# Construction des données
aliments = list(aliment_df.index)
nutriments = [col for col in aliment_df.columns if col != 'cout']
besoins = besoin_df['minimum'].to_dict()
cout = {i : aliment_df.loc[i, 'cout'] for i in aliments}

# Problème de minimisation
model = plp.LpProblem('Minisation_du_cout', plp.LpMinimize)

# Variables de décision
x = plp.LpVariable.dicts('x',  cout.keys(), lowBound=0, upBound = 300, cat='continuous')

# Fonction objectif
model += plp.lpSum([cout[i]*x[i] for i in aliments])

# Contraintes
for j in nutriments:
    model += plp.lpSum([aliment_df.loc[i, j]*x[i] for i in aliments]) >= besoins[j]

# Résolution
model.solve(solver)

# Résultat
print("Status : ", plp.LpStatus[model.status])
for i, var in x.items():   
    print(f"x[{i}] = {var.value()}") 
    
print("Coût Total : ", plp.value(model.objective))
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c591a319a8044a1dbc4f7cb0186e5b2b-pulp.lp -o /tmp/c591a319a8044a1dbc4f7cb0186e5b2b-pulp.out
#  -w /tmp/c591a319a8044a1dbc4f7cb0186e5b2b-pulp.sol
# Reading problem data from '/tmp/c591a319a8044a1dbc4f7cb0186e5b2b-pulp.lp'...
# 4 rows, 8 columns, 25 non-zeros
# 23 lines were read
# GLPK Simplex Optimizer 5.0
# 4 rows, 8 columns, 25 non-zeros
# Preprocessing...
# 4 rows, 8 columns, 25 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  8.840e+02  ratio =  8.840e+02
# GM: min|aij| =  2.856e-01  max|aij| =  3.502e+00  ratio =  1.226e+01
# EQ: min|aij| =  8.156e-02  max|aij| =  1.000e+00  ratio =  1.226e+01
# Constructing initial basis...
# Size of triangular part is 4
#       0: obj =   0.000000000e+00 inf =   5.838e+01 (4)
#       5: obj =   2.704869359e+00 inf =   0.000e+00 (0)
# *     8: obj =   1.689053870e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (39693 bytes)
# Writing basic solution to '/tmp/c591a319a8044a1dbc4f7cb0186e5b2b-pulp.out'...
# Writing basic solution to '/tmp/c591a319a8044a1dbc4f7cb0186e5b2b-pulp.sol'...
# 21 lines were written
# Status :  Optimal
# x[Poulet] = 0.0
# x[Riz] = 0.0
# x[Brocoli] = 0.0
# x[Oeufs] = 1.54125468803273
# x[Lentilles] = 0.0
# x[Saumon] = 0.0
# x[Huile_olive] = 0.130583020797818
# x[Pain_complet] = 6.66263211728606
# Coût Total :  1.6890538697579278
